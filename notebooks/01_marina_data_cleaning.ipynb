# %%
# Cell 1: Import from src
import sys
sys.path.append('..')
from src.data_cleaning import load_data, clean_data, handle_outliers, create_features, standardize_features

# Cell 2: Load and explore data
df = load_data('../data/raw/Crop yield data.xlsx')
df.head()  # Shows the data

# Cell 3: Clean data
df = clean_data(df)
df.head()  # Shows cleaned data

# Cell 4: Check quality
print(f"Missing values: {df.isnull().sum().sum()}")
print(f"Duplicates: {df.duplicated().sum()}")

# Cell 5: Outlier detection
# Visualize outliers with plots

# Cell 6: Feature engineering
df, le = create_features(df)
df.head()  # Shows new features

# Cell 7: Standardize
df_scaled, scaler = standardize_features(df, ['Rain Fall (mm)', 'Fertilizer', ...])
df_scaled.head()  # Shows scaled data

# Cell 8: Visualizations
import matplotlib.pyplot as plt
# ... plotting code ...
